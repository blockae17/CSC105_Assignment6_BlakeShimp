# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df =pd.read_csv("drive/My Drive/Notebooks/data/job_postings.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#       job_id  company_id                     title  \
# 0   85008768         NaN  Licensed Insurance Agent
# 1  133114754  77766802.0             Sales Manager
# 2  133196985   1089558.0        Model Risk Auditor
# 3  381055942  96654609.0          Business Manager
# 4  529257371   1244539.0       NY Studio Assistant
#
#                                          description  max_salary  med_salary  \
# 0  While many industries were hurt by the last fe...     52000.0         NaN
# 1  Are you a dynamic and creative marketing profe...         NaN         NaN
# 2  Join Us as a Model Risk Auditor – Showcase You...         NaN         NaN
# 3  Business ManagerFirst Baptist Church ForneyFor...         NaN         NaN
# 4  YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN         NaN
#
#    min_salary pay_period formatted_work_type           location  ...  \
# 0     45760.0     YEARLY           Full-time          Chico, CA  ...
# ...

# %%
df.tail()
# Out:
#            job_id  company_id                                  title  \
# 15881  3701373516  74718032.0                  Sanitation Technician
# 15882  3701373522     38897.0                         Unit Secretary
# 15883  3701373523     38897.0                Radiology Aide, Perdiem
# 15884  3701373524      2623.0                            MRI Manager
# 15885  3701373527     84659.0  Area Director of Business Development
#
#                                              description  max_salary  \
# 15881  Location:\n\nWest Columbia, SC, US, 29172\n\n2...         NaN
# 15882  Job Title: Unit Secretary\nDepartment: Nursing...         NaN
# 15883  Job Title: Radiology Aide, Perdiem\nDepartment...         NaN
# 15884  Grade 105\nJob Type: Officer of Administration...    135000.0
# 15885  Nexion Health Management affiliates operate 56...         NaN
#
#        med_salary  min_salary pay_period formatted_work_type  \
# 15881         NaN         NaN        NaN           Part-time
# ...

# %%
df.sample(5)
# Out:
#            job_id  company_id                                       title  \
# 9532   3697394066      1403.0                              Agile Engineer
# 13385  3701302662     15460.0  Senior Project Manager - Industrial Market
# 8197   3697363691  28978143.0         Per diem Central Sterile technician
# 2206   3693051422    571440.0                       Accounting Specialist
# 3968   3693070832  75156982.0                           Group Facilitator
#
#                                              description  max_salary  \
# 9532   Job Number: R0177989\nAgile Engineer\nKey Role...         NaN
# 13385  Our Industrial team’s architects and engineers...         NaN
# 8197   When you join the growing BILH team, you're no...         NaN
# 2206   Job Title: Accounting SpecialistReports To: CF...         NaN
# 3968                                         Facilitator         NaN
#
#        med_salary  min_salary pay_period formatted_work_type     location  \
# ...

# %%
df.columns
# Out:
# Index(['job_id', 'company_id', 'title', 'description', 'max_salary',
#        'med_salary', 'min_salary', 'pay_period', 'formatted_work_type',
#        'location', 'applies', 'original_listed_time', 'remote_allowed',
#        'views', 'job_posting_url', 'application_url', 'application_type',
#        'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type'],
#       dtype='object')

# %%
df[['title','min_salary','location']]
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %%
df2 = df[['title','min_salary','location']]

# %%
df2
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %%
df2[df2['title'] == "Sales Associate"]
# Out:
#                  title  min_salary           location
# 641    Sales Associate         NaN    Maple Grove, MN
# 1876   Sales Associate         NaN     Morgantown, WV
# 1877   Sales Associate         NaN      Strasburg, VA
# 2310   Sales Associate         NaN     Scottsdale, AZ
# 4048   Sales Associate         NaN  Daytona Beach, FL
# ...                ...         ...                ...
# 15249  Sales Associate        13.5        Atlanta, GA
# 15294  Sales Associate         NaN       Whittier, CA
# 15317  Sales Associate         NaN       Whittier, CA
# 15320  Sales Associate         NaN          Chino, CA
# 15343  Sales Associate        13.5     Pittsburgh, PA
#
# [64 rows x 3 columns]

# %%
df3 = df2[df2['title'] == "Sales Associate"]

# %%
df3
# Out:
#                  title  min_salary           location
# 641    Sales Associate         NaN    Maple Grove, MN
# 1876   Sales Associate         NaN     Morgantown, WV
# 1877   Sales Associate         NaN      Strasburg, VA
# 2310   Sales Associate         NaN     Scottsdale, AZ
# 4048   Sales Associate         NaN  Daytona Beach, FL
# ...                ...         ...                ...
# 15249  Sales Associate        13.5        Atlanta, GA
# 15294  Sales Associate         NaN       Whittier, CA
# 15317  Sales Associate         NaN       Whittier, CA
# 15320  Sales Associate         NaN          Chino, CA
# 15343  Sales Associate        13.5     Pittsburgh, PA
#
# [64 rows x 3 columns]

# %%
df3.isnull().sum()
# Out:
# title          0
# min_salary    54
# location       0
# dtype: int64

# %% [markdown]
# 54 of 64 Minimum salaries are missing within the dataset

# %%
df3.dropna()
# Out:
#                  title  min_salary                      location
# 5006   Sales Associate        20.0                    Boston, MA
# 6387   Sales Associate     50000.0                   Seattle, WA
# 6551   Sales Associate     50000.0    Miami-Fort Lauderdale Area
# 6911   Sales Associate        17.0             Redondo Beach, CA
# 11151  Sales Associate     50000.0                   Raleigh, NC
# 11259  Sales Associate     50000.0                   Chicago, IL
# 11401  Sales Associate     50000.0  Washington DC-Baltimore Area
# 11423  Sales Associate     50000.0                   Phoenix, AZ
# 15249  Sales Associate        13.5                   Atlanta, GA
# 15343  Sales Associate        13.5                Pittsburgh, PA

# %%
df3['min_salary'] < 20000
# Out:
# 641      False
# 1876     False
# 1877     False
# 2310     False
# 4048     False
#          ...
# 15249     True
# 15294    False
# 15317    False
# 15320    False
# 15343     True
# Name: min_salary, Length: 64, dtype: bool

# %%
df4 = df3[df3['min_salary'] > 20000]

# %%
df4
# Out:
#                  title  min_salary                      location
# 6387   Sales Associate     50000.0                   Seattle, WA
# 6551   Sales Associate     50000.0    Miami-Fort Lauderdale Area
# 11151  Sales Associate     50000.0                   Raleigh, NC
# 11259  Sales Associate     50000.0                   Chicago, IL
# 11401  Sales Associate     50000.0  Washington DC-Baltimore Area
# 11423  Sales Associate     50000.0                   Phoenix, AZ

# %% [markdown]
# The minimum salary for Sales Associates in Raleigh, North Carolina is 50,000
